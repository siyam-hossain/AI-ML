# %%
import os
cwd = os.getcwd()
print(f"current working directory is: {cwd}")
# Out:
# current working directory is: d:\Rat_Race\AI-ML\009-file-handling-in-python

# %% [markdown]
# + create a new directory

# %%
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory: \'{new_directory}\' create")
# Out:
# Directory: 'package' create

# %% [markdown]
# + listing files and directories

# %%
# . mean current directory
items = os.listdir('.')
print(items)

print("-"*100)
for item in items:
    print(item)
# Out:
# ['001-destination.txt', '001-example.bin', '001-example.txt', '001-file-operation.ipynb', '002-working-with-file-paths.ipynb', 'package']
# ----------------------------------------------------------------------------------------------------
# 001-destination.txt
# 001-example.bin
# 001-example.txt
# 001-file-operation.ipynb
# 002-working-with-file-paths.ipynb
# package

# %% [markdown]
# + joining paths

# %%
# relative paths
dir_name = "folder"
file_name = "file.txt"

full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name = "folder"
file_name = "file.txt"

full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# d:\Rat_Race\AI-ML\009-file-handling-in-python\folder\file.txt

# %% [markdown]
# + path exist or not

# %%
path = '001-example.txt'

if os.path.exists(path):
    print(f"the path \'{path}\' exist")
else:
    print(f"the path \'{path}\' does not exist")
# Out:
# the path '001-example.txt' exist

# %% [markdown]
# + checking if a path is a file or directory

# %%
path = '001-example.txt'

if os.path.isfile(path):
    print(f"the path \'{path}\' is a file")
elif os.path.isdir(path):
    print(f"the path \'{path}\' is a directory")
else:
    print(f"the path \'{path}\' is  neither a file nor a directory")
# Out:
# the path '001-example.txt' is a file

# %% [markdown]
# + getting absolute path

# %%
relative_path = '001-example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\Rat_Race\AI-ML\009-file-handling-in-python\001-example.txt
