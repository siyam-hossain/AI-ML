# %% [markdown]
# #### **Logging with multiple loggers**
#
# You can create multiple loggers for different parts of your application

# %%
import logging

# %% [markdown]
# ---
# + create a logger for module 1

# %%
logger1 = logging.getLogger('module1')
logger1.setLevel(logging.DEBUG)

# %% [markdown]
# ---
# + create a logger for module 2

# %%
logger2 = logging.getLogger('module2')
logger2.setLevel(logging.WARNING)

# %% [markdown]
# ---
# + configure logging settings

# %%
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s -%(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True
)

# %% [markdown]
# ---
# + log message with different loggers

# %%
logger1.debug('This is a debug message for module 1')
logger2.warning('This is a debug message for module 2')

logger2.error('This is an error message for module 2')
# Out:
# 2026-06-03 19:34:20 - module1 -DEBUG - This is a debug message for module 1
# 2026-06-03 19:34:20 - module2 -WARNING - This is a debug message for module 2
# 2026-06-03 19:34:20 - module2 -ERROR - This is an error message for module 2

# %% [markdown]
# Note:
#
# ```
# 2026-06-03 19:34:20 - module1 -DEBUG - This is a debug message for module 1
# 2026-06-03 19:34:20 - module2 -WARNING - This is a debug message for module 2
# 2026-06-03 19:34:20 - module2 -ERROR - This is an error message for module 2
# ```
#
#
# + previously it works on only root
# + but this case it works for all
