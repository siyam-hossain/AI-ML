# %% [markdown]
# #### **Python Logging**
#
# Logging is crucial aspect of any application, providing a way to tract events, errors, and operational information. Python's built-in logging module offers a flexible framework for emitting log messages from python programs. In this lesson, we will cover the basics of logging, including how to configure logging, log levels, and best practices for using logging in python application.

# %%
import logging

# %% [markdown]
# ---
# + configure basic logging settings

# %%
logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# + log message with different severity levels

# %%
# logging.basicConfig(level=logging.DEBUG)

logging.debug(" This is a debug message")
logging.info(" This an info message")
logging.warning(" This is a warning message")
logging.error(" This is an error message")
logging.critical(" This is a critical message")
# Out:
# DEBUG:root: This is a debug message
# INFO:root: This an info message
# WARNING:root: This is a warning message
# ERROR:root: This is an error message
# CRITICAL:root: This is a critical message

# %% [markdown]
# ---
# **Log levels**
#
# Python's logging module has several log levels indicating the severity of events. The default levels are:
#
# + **DEBUG**: detailed information, typically of interest only when diagnosing problems.
# + **INFO**: confirmation that things are working as expected.
# + **WARNING**: an indication that something unexpected happened or indicative of some problem in the near future. the software is still working as expected.
# + **ERROR**: due to a more serious problem, the software has not been able to perform some function.
# + **CRITICAL**: a very serious error, indicating that the program itself may be unable to continue running.

# %% [markdown]
# ---
# + configuring logging
# + The ```force=True``` argument (Python 3.8+) removes existing handlers and applies your configuration.

# %%
# configuring logging

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True
)

# log messages with different severity levels

logging.debug("This is a debug message")
logging.info("This an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
# Out:
# 2026-06-03 00:20:58-root-DEBUG-This is a debug message
# 2026-06-03 00:20:58-root-INFO-This an info message
# 2026-06-03 00:20:58-root-WARNING-This is a warning message
# 2026-06-03 00:20:58-root-ERROR-This is an error message
# 2026-06-03 00:20:58-root-CRITICAL-This is a critical message

# %%
# configuring logging

logging.basicConfig(
    filename='001-app-log',
    filemode='w',
    
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True
)

# log messages with different severity levels

logging.debug("This is a debug message")
logging.info("This an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
