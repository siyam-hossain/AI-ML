# %% [markdown]
# #### **Exception**
#
# Exception handling in python allows you to handle errors gracefully and take corrective actions without stopping the execution of the program. This lesson will cover the basics of exceptions, including how to use try, except, else, and finally blocks.
#
# **what are exceptions?**
#
# Exceptions are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
#
# + ZeroDivisionError: dividing by zero.
# + FileNotFoundError: file not found.
# + ValueError: invalid value
# + TypeError: invalid type

# %%
a = 10
# NameError
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 a = 10
# ----> 2 a = b
#
# NameError: name 'b' is not defined

# %% [markdown]
# + Exception try, except block

# %%
try:
    a=b
except:
    print("The variable is not defined")
# Out:
# The variable is not defined

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator grater than 0")
# Out:
# division by zero
# Please enter the denominator grater than 0

# %% [markdown]
# + when we don't know about what exception will occur
# + the we use Exception after except

# %%
try:
    result = 1/5
    a = b
except Exception as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result = 1/5
    a = b
except ZeroDivisionError as ex1:
    print(ex1)
except Exception as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    num = int(input("Enter a number: "))
    result = 10/num

    print(result)
except Exception as ex:
    print(ex)
# Out:
# 0.4

# %% [markdown]
# + try, except, else block

# %%
try:
    num = int(input("Enter a number: "))
    result = 10/num
except ValueError as ex1:
    print(ex1)
except ZeroDivisionError as ex2:
    print(ex2)
except Exception as ex:
    print(ex)
else:
    # if try block executed successfully then any how else block need to executed
    # otherwise if any except block raise else block own execute
    print(f"the result is {result}")
# Out:
# the result is 0.4

# %% [markdown]
# + try, except, else, finally

# %%
try:
    num = int(input("Enter a number: "))
    result = 10/num
except ValueError as ex1:
    print(ex1)
except ZeroDivisionError as ex2:
    print(ex2)
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")
finally:
    # whether or not any error raise finally block must be executed
    print("Execution complete")
# Out:
# division by zero
# Execution complete

# %% [markdown]
# + file handling and exception handling

# %%
try:
    file = open('example.txt','r')
    content = file.read()
    print(content)

except Exception as ex:
    print(ex)
finally:
    if 'file' in locals() or not file.close():
        file.close()
        print("file close")
# Out:
# file close
