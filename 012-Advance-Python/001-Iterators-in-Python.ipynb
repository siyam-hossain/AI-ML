# %% [markdown]
# #### **Iterators**
#
# Iterators are advanced python concepts that allow for efficient looping and memory management. Iterators provide a way to access elements of a collection sequentially without exposing the underlying structure.

# %%
my_list = list(range(1,7))

for i in my_list:
    print(i, end=" ")
print()

print(type(my_list))
# Out:
# 1 2 3 4 5 6
# <class 'list'>

# %%
print(my_list)
print(*my_list)
# Out:
# [1, 2, 3, 4, 5, 6]
# 1 2 3 4 5 6

# %% [markdown]
# + iterator

# %%
iterator = iter(my_list)

print(type(iterator))
# Out:
# <class 'list_iterator'>

# %% [markdown]
# + uses lazy loading technique

# %%
print(iterator)
# Out:
# <list_iterator object at 0x000002500CEBEEF0>

# %% [markdown]
# + iterate through all the element

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
next(iterator)
# Out:
# 1

# %%
next(iterator)
# Out:
# 2

# %%
next(iterator)
# Out:
# 3

# %%
next(iterator)
# Out:
# 4

# %%
next(iterator)
# Out:
# 5

# %%
next(iterator)
# Out:
# 6

# %%
next(iterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 next(iterator)
#
# StopIteration:

# %% [markdown]
# + to avoid this issue we use try except block

# %%
iterator = iter(my_list)

# %%
try:
    print(next(iterator))
except StopIteration:
    print("there are no elements in the iterator")
# Out:
# there are no elements in the iterator

# %% [markdown]
# + string iterator

# %%
my_string = "Hello"
string_iterator = iter(my_string)

print(next(string_iterator))
print(next(string_iterator))
# Out:
# H
# e
