# %% [markdown]
# #### **Magic Methods**
#
# Magic methods in python, also known as dunder methods (double underscore methods), are special methods tat start and end with double underscores. These methods enable you to define the behavior of objects for built-in operations, such as *arithmetic operations, comparisons, and more*.
#
# ##### **Magic methods**
#
# Magic methods are predefined methods in python that you can override to change the behavior of your objects. Some common magic methods include:
#
# ```python
#  __init__ : initializes a new instance of a class
#  __str__ : returns a string representation of an object.
#  __repr__ : returns an official string representation of an object
#  __getitem__ : gets an item fro a container
#  __setitem__ : gets an item from a container
#  __len__ : returns the length of an object
# ```

# %% [markdown]
# + let's all magic methods with the help of dir

# %%
class Magic:
    pass

magic = Magic()
dir(magic)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# + basic methods

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

person = Person('siyam','23')
print(person)

# %% [markdown]
# + we change default functionality by using ```__str__```

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    # over-written the default functionality
    # return default string representation
    def __str__(self):
        return f"name: {self.name}, age: {self.age}"    

person = Person('siyam','23')
print(person)
# Out:
# name: siyam, age: 23

# %% [markdown]
# + ```repr```

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def __str__(self):
        return f"name: {self.name}, age: {self.age}"    
    
    def __repr__(self):
        return f"Person(name={self.name}, age={self.age})"

person = Person('siyam','23')
print(repr(person))
# Out:
# Person(name=siyam, age=23)
